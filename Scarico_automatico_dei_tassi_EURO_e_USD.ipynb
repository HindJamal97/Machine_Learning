# %% [markdown]
# <a href="https://colab.research.google.com/github/HindJamal97/Machine_Learning/blob/main/Scarico_automatico_dei_tassi_EURO_e_USD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

# %%
from datetime import datetime

# %%
import pandas as pd

# %%
import openpyxl

# %%
 files.upload()

# %%
 files.upload()

# %% [markdown]
# ## ***SCARICO CURVE EURO***

# %%
df = pd.read_csv('/content/EUREuropeIndustrials.csv', parse_dates=['LAST_UPDATE_DT'])

# %%
df['LAST_UPDATE_DT'] = df['LAST_UPDATE_DT'].dt.strftime('%d-%m-%y')

# %%
df['LAST_UPDATE_DT'] = df['LAST_UPDATE_DT'].astype(str) + ' EUR'

# %%
df["PX_LAST_EOD"] = df["PX_LAST_EOD"].astype(str)

# %%
df['PX_LAST_EOD'] = df['PX_LAST_EOD'].apply(lambda x: x.replace('.', ','))

# %%
df
# Out:
#     DL_REQUEST_ID       DL_REQUEST_NAME DL_SNAPSHOT_START_TIME DL_SNAPSHOT_TZ  \
# 0    u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 1    u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 2    u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 3    u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 4    u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# ..            ...                   ...                    ...            ...
# 112  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 113  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 114  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 115  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 116  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
#
#               IDENTIFIER  RC LAST_UPDATE_DT PX_LAST_EOD
# 0    BVCWFW3M BVLI Index   0   17-04-24 EUR     4,15303
# 1    BVCWFW6M BVLI Index   0   17-04-24 EUR     4,12777
# 2    BVCWFW01 BVLI Index   0   17-04-24 EUR     4,07029
# 3    BVCWFW02 BVLI Index   0   17-04-24 EUR      3,9109
# 4    BVCWFW03 BVLI Index   0   17-04-24 EUR     3,78293
# ..                   ...  ..            ...         ...
# 112  BVCWFJ10 BVLI Index   0   17-04-24 EUR     3,49225
# 113  BVCWFJ15 BVLI Index   0   17-04-24 EUR     3,71659
# 114  BVCWFJ20 BVLI Index   0   17-04-24 EUR      3,9126
# 115  BVCWFJ25 BVLI Index   0   17-04-24 EUR     4,03549
# 116  BVCWFJ30 BVLI Index   0   17-04-24 EUR     4,24573
#
# [117 rows x 8 columns]

# %% [markdown]
# **Modalità di scarico delle curve con divisa EURO -- RATING A-**

# %%
DF = df[df['IDENTIFIER'].str.startswith('BVCWFJ')]

# %%
DF
# Out:
#     DL_REQUEST_ID       DL_REQUEST_NAME DL_SNAPSHOT_START_TIME DL_SNAPSHOT_TZ  \
# 102  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 103  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 104  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 105  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 106  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 107  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 108  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 109  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 110  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 111  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 112  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 113  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 114  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 115  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 116  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
#
#               IDENTIFIER  RC LAST_UPDATE_DT PX_LAST_EOD
# 102  BVCWFJ3M BVLI Index   0   17-04-24 EUR     3,81743
# 103  BVCWFJ6M BVLI Index   0   17-04-24 EUR     3,79447
# 104  BVCWFJ01 BVLI Index   0   17-04-24 EUR     3,74505
# 105  BVCWFJ02 BVLI Index   0   17-04-24 EUR     3,57095
# 106  BVCWFJ03 BVLI Index   0   17-04-24 EUR     3,41146
# 107  BVCWFJ04 BVLI Index   0   17-04-24 EUR      3,3273
# 108  BVCWFJ05 BVLI Index   0   17-04-24 EUR     3,31942
# 109  BVCWFJ07 BVLI Index   0   17-04-24 EUR     3,39663
# 110  BVCWFJ08 BVLI Index   0   17-04-24 EUR      3,4374
# 111  BVCWFJ09 BVLI Index   0   17-04-24 EUR     3,46341
# 112  BVCWFJ10 BVLI Index   0   17-04-24 EUR     3,49225
# 113  BVCWFJ15 BVLI Index   0   17-04-24 EUR     3,71659
# 114  BVCWFJ20 BVLI Index   0   17-04-24 EUR      3,9126
# 115  BVCWFJ25 BVLI Index   0   17-04-24 EUR     4,03549
# 116  BVCWFJ30 BVLI Index   0   17-04-24 EUR     4,24573

# %%
Data = DF.drop(columns=["DL_REQUEST_ID", "DL_REQUEST_NAME", "DL_SNAPSHOT_TZ", "DL_SNAPSHOT_START_TIME", "RC", "IDENTIFIER", "DL_SNAPSHOT_START_TIME","LAST_UPDATE_DT"])

# %%
DATA = Data.transpose()

# %%
DATA
# Out:
#                  102      103      104      105      106     107      108  \
# PX_LAST_EOD  3,81743  3,79447  3,74505  3,57095  3,41146  3,3273  3,31942
#
#                  109     110      111      112      113     114      115  \
# PX_LAST_EOD  3,39663  3,4374  3,46341  3,49225  3,71659  3,9126  4,03549
#
#                  116
# PX_LAST_EOD  4,24573

# %%
file_name = 'tassi-Ameno-EUR.xlsx'

# %%
DATA.to_excel(file_name)
print('DataFrame is written to Excel File successfully.')
# Out:
# DataFrame is written to Excel File successfully.

# %%
# opening the source excel file
wbo = openpyxl.load_workbook(file_name)

# %%
#attach the ranges to the sheet
wso = wbo["Sheet1"]["B2":"P2"]

# %%
# opening the destination excel file
wbd = openpyxl.load_workbook("/content/Condizioni economiche Fin. IC BREVE E MLT Eni II trimestre 2024.xlsx", keep_vba=True)

# %%
tab_name = df.at[0, 'LAST_UPDATE_DT']

# %%
#attach the ranges to the sheet
wsd = wbd[tab_name]["C4":"Q4"]

# %%
#step1 : pair the rows
for row1,row2 in zip(wso,wsd):
    #within the row pair, pair the cells
    for cell1, cell2 in zip(row1,row2): cell2.value = cell1.value

# %%
#save document
wbd.save('Condizioni economiche Fin. IC BREVE E MLT Eni II trimestre 2024.xlsm')

# %% [markdown]
# **Modalità di scarico delle curve con divisa EURO -- RATING BBB+**

# %%
DF = df[df['IDENTIFIER'].str.startswith('BVCWFX')]

# %%
DF
# Out:
#    DL_REQUEST_ID       DL_REQUEST_NAME DL_SNAPSHOT_START_TIME DL_SNAPSHOT_TZ  \
# 74  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 75  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 76  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 77  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 78  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 79  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 80  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 81  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 82  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 83  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 84  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 85  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 86  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 87  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
#
#              IDENTIFIER  RC LAST_UPDATE_DT PX_LAST_EOD
# 74  BVCWFX3M BVLI Index   0   17-04-24 EUR     3,83743
# 75  BVCWFX6M BVLI Index   0   17-04-24 EUR     3,81447
# 76  BVCWFX01 BVLI Index   0   17-04-24 EUR     3,76505
# 77  BVCWFX02 BVLI Index   0   17-04-24 EUR     3,74418
# 78  BVCWFX03 BVLI Index   0   17-04-24 EUR     3,62008
# 79  BVCWFX04 BVLI Index   0   17-04-24 EUR     3,59264
# 80  BVCWFX05 BVLI Index   0   17-04-24 EUR     3,60704
# 81  BVCWFX07 BVLI Index   0   17-04-24 EUR     3,63896
# 82  BVCWFX09 BVLI Index   0   17-04-24 EUR     3,69761
# 83  BVCWFX10 BVLI Index   0   17-04-24 EUR     3,72632
# 84  BVCWFX15 BVLI Index   0   17-04-24 EUR     3,89875
# 85  BVCWFX20 BVLI Index   0   17-04-24 EUR     4,09002
# 86  BVCWFX25 BVLI Index   0   17-04-24 EUR     4,24251
# 87  BVCWFX30 BVLI Index   0   17-04-24 EUR      4,4865

# %%
Data = DF.drop(columns=["DL_REQUEST_ID", "DL_REQUEST_NAME", "DL_SNAPSHOT_TZ", "DL_SNAPSHOT_START_TIME", "RC", "IDENTIFIER", "DL_SNAPSHOT_START_TIME","LAST_UPDATE_DT"])

# %%
DATA = Data.transpose()

# %%
value = [0]

# %%
DATA.insert(8,'New_Column', value)

# %%
DATA
# Out:
#                   74       75       76       77       78       79       80  \
# PX_LAST_EOD  3,83743  3,81447  3,76505  3,74418  3,62008  3,59264  3,60704
#
#                   81  New_Column       82       83       84       85       86  \
# PX_LAST_EOD  3,63896           0  3,69761  3,72632  3,89875  4,09002  4,24251
#
#                  87
# PX_LAST_EOD  4,4865

# %%
file_name = 'tassi-BBBpiu-EUR.xlsx'

# %%
DATA.to_excel(file_name)
print('DataFrame is written to Excel File successfully.')
# Out:
# DataFrame is written to Excel File successfully.

# %%
# opening the source excel file
wbo = openpyxl.load_workbook(file_name)

# %%
#attach the ranges to the sheet
wso = wbo["Sheet1"]["B2":"P2"]

# %%
# opening the destination excel file
wbd = openpyxl.load_workbook("/content/Condizioni economiche Fin. IC BREVE E MLT Eni II trimestre 2024.xlsm", keep_vba=True)

# %%
tab_name = df.at[0, 'LAST_UPDATE_DT']

# %%
#attach the ranges to the sheet
wsd = wbd[tab_name]["C5":"Q5"]

# %%
#step1 : pair the rows
for row1,row2 in zip(wso,wsd):
    #within the row pair, pair the cells
    for cell1, cell2 in zip(row1,row2): cell2.value = cell1.value

# %%
#save document
wbd.save('Condizioni economiche Fin. IC BREVE E MLT Eni II trimestre 2024.xlsm')

# %% [markdown]
# **Modalità di scarico delle curve con divisa EURO -- RATING BBB**

# %%
DF = df[df['IDENTIFIER'].str.startswith('BVCWFV')]

# %%
DF
# Out:
#     DL_REQUEST_ID       DL_REQUEST_NAME DL_SNAPSHOT_START_TIME DL_SNAPSHOT_TZ  \
# 88   u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 89   u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 90   u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 91   u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 92   u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 93   u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 94   u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 95   u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 96   u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 97   u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 98   u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 99   u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 100  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 101  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
#
#               IDENTIFIER  RC LAST_UPDATE_DT PX_LAST_EOD
# 88   BVCWFV3M BVLI Index   0   17-04-24 EUR     3,85743
# 89   BVCWFV6M BVLI Index   0   17-04-24 EUR     3,83447
# 90   BVCWFV01 BVLI Index   0   17-04-24 EUR     3,84447
# 91   BVCWFV02 BVLI Index   0   17-04-24 EUR     3,76515
# 92   BVCWFV03 BVLI Index   0   17-04-24 EUR     3,65192
# 93   BVCWFV04 BVLI Index   0   17-04-24 EUR     3,61265
# 94   BVCWFV05 BVLI Index   0   17-04-24 EUR     3,62704
# 95   BVCWFV07 BVLI Index   0   17-04-24 EUR     3,65896
# 96   BVCWFV09 BVLI Index   0   17-04-24 EUR     3,71762
# 97   BVCWFV10 BVLI Index   0   17-04-24 EUR     3,74632
# 98   BVCWFV15 BVLI Index   0   17-04-24 EUR     3,91875
# 99   BVCWFV20 BVLI Index   0   17-04-24 EUR     4,11002
# 100  BVCWFV25 BVLI Index   0   17-04-24 EUR     4,26251
# 101  BVCWFV30 BVLI Index   0   17-04-24 EUR      4,5065

# %%
Data = DF.drop(columns=["DL_REQUEST_ID", "DL_REQUEST_NAME", "DL_SNAPSHOT_TZ", "DL_SNAPSHOT_START_TIME", "RC", "IDENTIFIER", "DL_SNAPSHOT_START_TIME","LAST_UPDATE_DT"])

# %%
Data = DF.drop(columns=["DL_REQUEST_ID", "DL_REQUEST_NAME", "DL_SNAPSHOT_TZ", "DL_SNAPSHOT_START_TIME", "RC", "IDENTIFIER", "DL_SNAPSHOT_START_TIME","LAST_UPDATE_DT"])

# %%
DATA = Data.transpose()

# %%
value = [0]

# %%
DATA.insert(8,'New_Column', value)

# %%
DATA
# Out:
#                   88       89       90       91       92       93       94  \
# PX_LAST_EOD  3,85743  3,83447  3,84447  3,76515  3,65192  3,61265  3,62704
#
#                   95  New_Column       96       97       98       99      100  \
# PX_LAST_EOD  3,65896           0  3,71762  3,74632  3,91875  4,11002  4,26251
#
#                 101
# PX_LAST_EOD  4,5065

# %%
file_name = 'tassi-BBB-EUR.xlsx'

# %%
DATA.to_excel(file_name)
print('DataFrame is written to Excel File successfully.')
# Out:
# DataFrame is written to Excel File successfully.

# %%
# opening the source excel file
wbo = openpyxl.load_workbook(file_name)

# %%
#attach the ranges to the sheet
wso = wbo["Sheet1"]["B2":"P2"]

# %%
# opening the destination excel file
wbd = openpyxl.load_workbook("/content/Condizioni economiche Fin. IC BREVE E MLT Eni II trimestre 2024.xlsm", keep_vba=True)

# %%
tab_name = df.at[0, 'LAST_UPDATE_DT']

# %%
print(tab_name)
# Out:
# 17-04-24 EUR

# %%
#attach the ranges to the sheet
wsd = wbd[tab_name]["C6":"Q6"]

# %%
#step1 : pair the rows
for row1,row2 in zip(wso,wsd):
    #within the row pair, pair the cells
    for cell1, cell2 in zip(row1,row2): cell2.value = cell1.value

# %%
#save document
wbd.save('Condizioni economiche Fin. IC BREVE E MLT Eni II trimestre 2024.xlsm')

# %% [markdown]
# **Modalità di scarico delle curve con divisa EURO -- RATING BBB-**

# %%
DF = df[df['IDENTIFIER'].str.startswith('BVCWFW')]

# %%
DF
# Out:
#    DL_REQUEST_ID       DL_REQUEST_NAME DL_SNAPSHOT_START_TIME DL_SNAPSHOT_TZ  \
# 0   u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 1   u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 2   u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 3   u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 4   u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 5   u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 6   u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 7   u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 8   u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 9   u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 10  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 11  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 12  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 13  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
#
#              IDENTIFIER  RC LAST_UPDATE_DT PX_LAST_EOD
# 0   BVCWFW3M BVLI Index   0   17-04-24 EUR     4,15303
# 1   BVCWFW6M BVLI Index   0   17-04-24 EUR     4,12777
# 2   BVCWFW01 BVLI Index   0   17-04-24 EUR     4,07029
# 3   BVCWFW02 BVLI Index   0   17-04-24 EUR      3,9109
# 4   BVCWFW03 BVLI Index   0   17-04-24 EUR     3,78293
# 5   BVCWFW04 BVLI Index   0   17-04-24 EUR     3,78011
# 6   BVCWFW05 BVLI Index   0   17-04-24 EUR     3,82437
# 7   BVCWFW07 BVLI Index   0   17-04-24 EUR     3,91252
# 8   BVCWFW09 BVLI Index   0   17-04-24 EUR     4,00355
# 9   BVCWFW10 BVLI Index   0   17-04-24 EUR     4,01402
# 10  BVCWFW15 BVLI Index   0   17-04-24 EUR     4,12874
# 11  BVCWFW20 BVLI Index   0   17-04-24 EUR     4,31069
# 12  BVCWFW25 BVLI Index   0   17-04-24 EUR      4,4856
# 13  BVCWFW30 BVLI Index   0   17-04-24 EUR     4,76261

# %%
Data = DF.drop(columns=["DL_REQUEST_ID", "DL_REQUEST_NAME", "DL_SNAPSHOT_TZ", "DL_SNAPSHOT_START_TIME", "RC", "IDENTIFIER", "DL_SNAPSHOT_START_TIME","LAST_UPDATE_DT"])

# %%
Data = DF.drop(columns=["DL_REQUEST_ID", "DL_REQUEST_NAME", "DL_SNAPSHOT_TZ", "DL_SNAPSHOT_START_TIME", "RC", "IDENTIFIER", "DL_SNAPSHOT_START_TIME","LAST_UPDATE_DT"])

# %%
DATA = Data.transpose()

# %%
value = [0]

# %%
DATA.insert(8,'New_Column', value)

# %%
DATA
# Out:
#                    0        1        2       3        4        5        6  \
# PX_LAST_EOD  4,15303  4,12777  4,07029  3,9109  3,78293  3,78011  3,82437
#
#                    7  New_Column        8        9       10       11      12  \
# PX_LAST_EOD  3,91252           0  4,00355  4,01402  4,12874  4,31069  4,4856
#
#                   13
# PX_LAST_EOD  4,76261

# %%
file_name = 'tassi-BBBmeno-EUR.xlsx'

# %%
DATA.to_excel(file_name)
print('DataFrame is written to Excel File successfully.')
# Out:
# DataFrame is written to Excel File successfully.

# %%
# opening the source excel file
wbo = openpyxl.load_workbook(file_name)

# %%
#attach the ranges to the sheet
wso = wbo["Sheet1"]["B2":"P2"]

# %%
# opening the destination excel file
wbd = openpyxl.load_workbook("/content/Condizioni economiche Fin. IC BREVE E MLT Eni II trimestre 2024.xlsm", keep_vba=True)

# %%
tab_name = df.at[0, 'LAST_UPDATE_DT']

# %%
print(tab_name)
# Out:
# 17-04-24 EUR

# %%
#attach the ranges to the sheet
wsd = wbd[tab_name]["C7":"Q7"]

# %%
#step1 : pair the rows
for row1,row2 in zip(wso,wsd):
    #within the row pair, pair the cells
    for cell1, cell2 in zip(row1,row2): cell2.value = cell1.value

# %%
#save document
wbd.save('Condizioni economiche Fin. IC BREVE E MLT Eni II trimestre 2024.xlsm')

# %% [markdown]
# **Modalità di scarico delle curve con divisa EURO -- RATING BB+**

# %%
DF = df[df['IDENTIFIER'].str.startswith('BVCWFU')]

# %%
DF
# Out:
#    DL_REQUEST_ID       DL_REQUEST_NAME DL_SNAPSHOT_START_TIME DL_SNAPSHOT_TZ  \
# 62  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 63  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 64  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 65  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 66  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 67  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 68  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 69  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 70  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 71  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 72  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 73  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
#
#              IDENTIFIER  RC LAST_UPDATE_DT PX_LAST_EOD
# 62  BVCWFU3M BVLI Index   0   17-04-24 EUR     4,36417
# 63  BVCWFU6M BVLI Index   0   17-04-24 EUR     4,40007
# 64  BVCWFU01 BVLI Index   0   17-04-24 EUR     4,46317
# 65  BVCWFU02 BVLI Index   0   17-04-24 EUR     4,43227
# 66  BVCWFU03 BVLI Index   0   17-04-24 EUR     4,37567
# 67  BVCWFU04 BVLI Index   0   17-04-24 EUR     4,48971
# 68  BVCWFU05 BVLI Index   0   17-04-24 EUR     4,47496
# 69  BVCWFU07 BVLI Index   0   17-04-24 EUR     4,41859
# 70  BVCWFU08 BVLI Index   0   17-04-24 EUR     4,42741
# 71  BVCWFU09 BVLI Index   0   17-04-24 EUR     4,43018
# 72  BVCWFU10 BVLI Index   0   17-04-24 EUR     4,43645
# 73  BVCWFU15 BVLI Index   0   17-04-24 EUR     4,55876

# %%
Data = DF.drop(columns=["DL_REQUEST_ID", "DL_REQUEST_NAME", "DL_SNAPSHOT_TZ", "DL_SNAPSHOT_START_TIME", "RC", "IDENTIFIER", "DL_SNAPSHOT_START_TIME","LAST_UPDATE_DT"])

# %%
Data = DF.drop(columns=["DL_REQUEST_ID", "DL_REQUEST_NAME", "DL_SNAPSHOT_TZ", "DL_SNAPSHOT_START_TIME", "RC", "IDENTIFIER", "DL_SNAPSHOT_START_TIME","LAST_UPDATE_DT"])

# %%
DATA = Data.transpose()

# %%
DATA
# Out:
#                   62       63       64       65       66       67       68  \
# PX_LAST_EOD  4,36417  4,40007  4,46317  4,43227  4,37567  4,48971  4,47496
#
#                   69       70       71       72       73
# PX_LAST_EOD  4,41859  4,42741  4,43018  4,43645  4,55876

# %%
file_name = 'tassi-BBpiu-EUR.xlsx'

# %%
DATA.to_excel(file_name)
print('DataFrame is written to Excel File successfully.')
# Out:
# DataFrame is written to Excel File successfully.

# %%
# opening the source excel file
wbo = openpyxl.load_workbook(file_name)

# %%
#attach the ranges to the sheet
wso = wbo["Sheet1"]["B2":"P2"]

# %%
# opening the destination excel file
wbd = openpyxl.load_workbook("/content/Condizioni economiche Fin. IC BREVE E MLT Eni II trimestre 2024.xlsm", keep_vba=True)

# %%
tab_name = df.at[0, 'LAST_UPDATE_DT']

# %%
print(tab_name)
# Out:
# 17-04-24 EUR

# %%
#attach the ranges to the sheet
wsd = wbd[tab_name]["C8":"Q8"]

# %%
#step1 : pair the rows
for row1,row2 in zip(wso,wsd):
    #within the row pair, pair the cells
    for cell1, cell2 in zip(row1,row2): cell2.value = cell1.value

# %%
#save document
wbd.save('Condizioni economiche Fin. IC BREVE E MLT Eni II trimestre 2024.xlsm')

# %% [markdown]
# **Modalità di scarico delle curve con divisa EURO -- RATING BB**

# %%
DF = df[df['IDENTIFIER'].str.startswith('BVCWFS')]

# %%
DF
# Out:
#    DL_REQUEST_ID       DL_REQUEST_NAME DL_SNAPSHOT_START_TIME DL_SNAPSHOT_TZ  \
# 38  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 39  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 40  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 41  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 42  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 43  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 44  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 45  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 46  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 47  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 48  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 49  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
#
#              IDENTIFIER  RC LAST_UPDATE_DT PX_LAST_EOD
# 38  BVCWFS3M BVLI Index   0   17-04-24 EUR     4,40658
# 39  BVCWFS6M BVLI Index   0   17-04-24 EUR     4,45246
# 40  BVCWFS01 BVLI Index   0   17-04-24 EUR     4,57857
# 41  BVCWFS02 BVLI Index   0   17-04-24 EUR     4,75106
# 42  BVCWFS03 BVLI Index   0   17-04-24 EUR     4,78074
# 43  BVCWFS04 BVLI Index   0   17-04-24 EUR     4,82468
# 44  BVCWFS05 BVLI Index   0   17-04-24 EUR     4,80705
# 45  BVCWFS07 BVLI Index   0   17-04-24 EUR     4,74969
# 46  BVCWFS08 BVLI Index   0   17-04-24 EUR     4,75417
# 47  BVCWFS09 BVLI Index   0   17-04-24 EUR     4,75535
# 48  BVCWFS10 BVLI Index   0   17-04-24 EUR     4,76432
# 49  BVCWFS15 BVLI Index   0   17-04-24 EUR     4,91356

# %%
Data = DF.drop(columns=["DL_REQUEST_ID", "DL_REQUEST_NAME", "DL_SNAPSHOT_TZ", "DL_SNAPSHOT_START_TIME", "RC", "IDENTIFIER", "DL_SNAPSHOT_START_TIME","LAST_UPDATE_DT"])

# %%
DATA = Data.transpose()

# %%
DATA
# Out:
#                   38       39       40       41       42       43       44  \
# PX_LAST_EOD  4,40658  4,45246  4,57857  4,75106  4,78074  4,82468  4,80705
#
#                   45       46       47       48       49
# PX_LAST_EOD  4,74969  4,75417  4,75535  4,76432  4,91356

# %%
file_name = 'tassi-BB-EUR.xlsx'

# %%
DATA.to_excel(file_name)
print('DataFrame is written to Excel File successfully.')
# Out:
# DataFrame is written to Excel File successfully.

# %%
# opening the source excel file
wbo = openpyxl.load_workbook(file_name)

# %%
#attach the ranges to the sheet
wso = wbo["Sheet1"]["B2":"P2"]

# %%
# opening the destination excel file
wbd = openpyxl.load_workbook("/content/Condizioni economiche Fin. IC BREVE E MLT Eni II trimestre 2024.xlsm", keep_vba=True)

# %%
tab_name = df.at[0, 'LAST_UPDATE_DT']

# %%
print(tab_name)
# Out:
# 17-04-24 EUR

# %%
#attach the ranges to the sheet
wsd = wbd[tab_name]["C9":"Q9"]

# %%
#step1 : pair the rows
for row1,row2 in zip(wso,wsd):
    #within the row pair, pair the cells
    for cell1, cell2 in zip(row1,row2): cell2.value = cell1.value

# %%
#save document
wbd.save('Condizioni economiche Fin. IC BREVE E MLT Eni II trimestre 2024.xlsm')

# %% [markdown]
# **Modalità di scarico delle curve con divisa EURO -- RATING BB-**

# %%
DF = df[df['IDENTIFIER'].str.startswith('BVCWFT')]

# %%
DF
# Out:
#    DL_REQUEST_ID       DL_REQUEST_NAME DL_SNAPSHOT_START_TIME DL_SNAPSHOT_TZ  \
# 50  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 51  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 52  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 53  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 54  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 55  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 56  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 57  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 58  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 59  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 60  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 61  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
#
#              IDENTIFIER  RC LAST_UPDATE_DT PX_LAST_EOD
# 50  BVCWFT3M BVLI Index   0   17-04-24 EUR     4,48203
# 51  BVCWFT6M BVLI Index   0   17-04-24 EUR     4,52895
# 52  BVCWFT01 BVLI Index   0   17-04-24 EUR     4,63604
# 53  BVCWFT02 BVLI Index   0   17-04-24 EUR     4,80455
# 54  BVCWFT03 BVLI Index   0   17-04-24 EUR     4,87679
# 55  BVCWFT04 BVLI Index   0   17-04-24 EUR     4,95903
# 56  BVCWFT05 BVLI Index   0   17-04-24 EUR     4,97986
# 57  BVCWFT07 BVLI Index   0   17-04-24 EUR     4,95471
# 58  BVCWFT08 BVLI Index   0   17-04-24 EUR     4,96031
# 59  BVCWFT09 BVLI Index   0   17-04-24 EUR     4,95719
# 60  BVCWFT10 BVLI Index   0   17-04-24 EUR     4,95603
# 61  BVCWFT15 BVLI Index   0   17-04-24 EUR     5,09426

# %%
Data = DF.drop(columns=["DL_REQUEST_ID", "DL_REQUEST_NAME", "DL_SNAPSHOT_TZ", "DL_SNAPSHOT_START_TIME", "RC", "IDENTIFIER", "DL_SNAPSHOT_START_TIME","LAST_UPDATE_DT"])

# %%
DATA = Data.transpose()

# %%
DATA
# Out:
#                   50       51       52       53       54       55       56  \
# PX_LAST_EOD  4,48203  4,52895  4,63604  4,80455  4,87679  4,95903  4,97986
#
#                   57       58       59       60       61
# PX_LAST_EOD  4,95471  4,96031  4,95719  4,95603  5,09426

# %%
file_name = 'tassi-BBmeno-EUR.xlsx'

# %%
DATA.to_excel(file_name)
print('DataFrame is written to Excel File successfully.')
# Out:
# DataFrame is written to Excel File successfully.

# %%
# opening the source excel file
wbo = openpyxl.load_workbook(file_name)

# %%
#attach the ranges to the sheet
wso = wbo["Sheet1"]["B2":"P2"]

# %%
# opening the destination excel file
wbd = openpyxl.load_workbook("/content/Condizioni economiche Fin. IC BREVE E MLT Eni II trimestre 2024.xlsm", keep_vba=True)

# %%
tab_name = df.at[0, 'LAST_UPDATE_DT']

# %%
print(tab_name)
# Out:
# 17-04-24 EUR

# %%
#attach the ranges to the sheet
wsd = wbd[tab_name]["C10":"Q10"]

# %%
#step1 : pair the rows
for row1,row2 in zip(wso,wsd):
    #within the row pair, pair the cells
    for cell1, cell2 in zip(row1,row2): cell2.value = cell1.value

# %%
#save document
wbd.save('Condizioni economiche Fin. IC BREVE E MLT Eni II trimestre 2024.xlsm')

# %% [markdown]
# **Modalità di scarico delle curve con divisa EURO -- RATING B+**

# %%
DF = df[df['IDENTIFIER'].str.startswith('BVCWFR')]

# %%
DF
# Out:
#    DL_REQUEST_ID       DL_REQUEST_NAME DL_SNAPSHOT_START_TIME DL_SNAPSHOT_TZ  \
# 26  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 27  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 28  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 29  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 30  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 31  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 32  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 33  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 34  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 35  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 36  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 37  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
#
#              IDENTIFIER  RC LAST_UPDATE_DT PX_LAST_EOD
# 26  BVCWFR3M BVLI Index   0   17-04-24 EUR     4,59835
# 27  BVCWFR6M BVLI Index   0   17-04-24 EUR     4,63329
# 28  BVCWFR01 BVLI Index   0   17-04-24 EUR      4,7214
# 29  BVCWFR02 BVLI Index   0   17-04-24 EUR     4,84216
# 30  BVCWFR03 BVLI Index   0   17-04-24 EUR     5,04684
# 31  BVCWFR04 BVLI Index   0   17-04-24 EUR      5,1661
# 32  BVCWFR05 BVLI Index   0   17-04-24 EUR     5,22705
# 33  BVCWFR07 BVLI Index   0   17-04-24 EUR     5,25581
# 34  BVCWFR08 BVLI Index   0   17-04-24 EUR     5,25818
# 35  BVCWFR09 BVLI Index   0   17-04-24 EUR     5,24437
# 36  BVCWFR10 BVLI Index   0   17-04-24 EUR     5,22465
# 37  BVCWFR15 BVLI Index   0   17-04-24 EUR     5,34483

# %%
Data = DF.drop(columns=["DL_REQUEST_ID", "DL_REQUEST_NAME", "DL_SNAPSHOT_TZ", "DL_SNAPSHOT_START_TIME", "RC", "IDENTIFIER", "DL_SNAPSHOT_START_TIME","LAST_UPDATE_DT"])

# %%
DATA = Data.transpose()

# %%
DATA
# Out:
#                   26       27      28       29       30      31       32  \
# PX_LAST_EOD  4,59835  4,63329  4,7214  4,84216  5,04684  5,1661  5,22705
#
#                   33       34       35       36       37
# PX_LAST_EOD  5,25581  5,25818  5,24437  5,22465  5,34483

# %%
file_name = 'tassi-Bpiu-EUR.xlsx'

# %%
DATA.to_excel(file_name)
print('DataFrame is written to Excel File successfully.')
# Out:
# DataFrame is written to Excel File successfully.

# %%
# opening the source excel file
wbo = openpyxl.load_workbook(file_name)

# %%
#attach the ranges to the sheet
wso = wbo["Sheet1"]["B2":"P2"]

# %%
# opening the destination excel file
wbd = openpyxl.load_workbook("/content/Condizioni economiche Fin. IC BREVE E MLT Eni II trimestre 2024.xlsm", keep_vba=True)

# %%
tab_name = df.at[0, 'LAST_UPDATE_DT']

# %%
print(tab_name)
# Out:
# 17-04-24 EUR

# %%
#attach the ranges to the sheet
wsd = wbd[tab_name]["C11":"Q11"]

# %%
#step1 : pair the rows
for row1,row2 in zip(wso,wsd):
    #within the row pair, pair the cells
    for cell1, cell2 in zip(row1,row2): cell2.value = cell1.value

# %%
#save document
wbd.save('Condizioni economiche Fin. IC BREVE E MLT Eni II trimestre 2024.xlsm')

# %% [markdown]
# **Modalità di scarico delle curve con divisa EURO -- RATING B**

# %%
DF = df[df['IDENTIFIER'].str.startswith('BVCWFP')]

# %%
DF
# Out:
#    DL_REQUEST_ID       DL_REQUEST_NAME DL_SNAPSHOT_START_TIME DL_SNAPSHOT_TZ  \
# 14  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 15  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 16  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 17  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 18  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 19  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 20  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 21  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 22  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 23  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 24  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
# 25  u7b5AYYop8br  EUREuropeIndustrials    2024-04-18T16:35:31            BST
#
#              IDENTIFIER  RC LAST_UPDATE_DT PX_LAST_EOD
# 14  BVCWFP3M BVLI Index   0   17-04-24 EUR      4,6945
# 15  BVCWFP6M BVLI Index   0   17-04-24 EUR     4,71507
# 16  BVCWFP01 BVLI Index   0   17-04-24 EUR     4,79563
# 17  BVCWFP02 BVLI Index   0   17-04-24 EUR     4,88255
# 18  BVCWFP03 BVLI Index   0   17-04-24 EUR     5,10866
# 19  BVCWFP04 BVLI Index   0   17-04-24 EUR       5,231
# 20  BVCWFP05 BVLI Index   0   17-04-24 EUR     5,30146
# 21  BVCWFP07 BVLI Index   0   17-04-24 EUR     5,37622
# 22  BVCWFP08 BVLI Index   0   17-04-24 EUR     5,38186
# 23  BVCWFP09 BVLI Index   0   17-04-24 EUR     5,37432
# 24  BVCWFP10 BVLI Index   0   17-04-24 EUR     5,35347
# 25  BVCWFP15 BVLI Index   0   17-04-24 EUR     5,47185

# %%
Data = DF.drop(columns=["DL_REQUEST_ID", "DL_REQUEST_NAME", "DL_SNAPSHOT_TZ", "DL_SNAPSHOT_START_TIME", "RC", "IDENTIFIER", "DL_SNAPSHOT_START_TIME","LAST_UPDATE_DT"])

# %%
DATA = Data.transpose()

# %%
DATA
# Out:
#                  14       15       16       17       18     19       20  \
# PX_LAST_EOD  4,6945  4,71507  4,79563  4,88255  5,10866  5,231  5,30146
#
#                   21       22       23       24       25
# PX_LAST_EOD  5,37622  5,38186  5,37432  5,35347  5,47185

# %%
file_name = 'tassi-B-EUR.xlsx'

# %%
DATA.to_excel(file_name)
print('DataFrame is written to Excel File successfully.')
# Out:
# DataFrame is written to Excel File successfully.

# %%
# opening the source excel file
wbo = openpyxl.load_workbook(file_name)

# %%
#attach the ranges to the sheet
wso = wbo["Sheet1"]["B2":"P2"]

# %%
# opening the destination excel file
wbd = openpyxl.load_workbook("/content/Condizioni economiche Fin. IC BREVE E MLT Eni II trimestre 2024.xlsm", keep_vba=True)

# %%
tab_name = df.at[0, 'LAST_UPDATE_DT']

# %%
print(tab_name)
# Out:
# 17-04-24 EUR

# %%
#attach the ranges to the sheet
wsd = wbd[tab_name]["C12":"Q12"]

# %%
#step1 : pair the rows
for row1,row2 in zip(wso,wsd):
    #within the row pair, pair the cells
    for cell1, cell2 in zip(row1,row2): cell2.value = cell1.value

# %%
#save document
wbd.save('Condizioni economiche Fin. IC BREVE E MLT Eni II trimestre 2024.xlsm')

# %% [markdown]
# ## ***SCARICO DIVISA USD***

# %%
df = pd.read_csv('/content/USDUSAIndustrials.csv', parse_dates=['LAST_UPDATE_DT'])

# %%
df['LAST_UPDATE_DT'] = df['LAST_UPDATE_DT'].dt.strftime('%d-%m-%y')

# %%
df['LAST_UPDATE_DT'] = df['LAST_UPDATE_DT'].astype(str) + ' USD'

# %%
df["PX_LAST_EOD"] = df["PX_LAST_EOD"].astype(str)

# %%
df['PX_LAST_EOD'] = df['PX_LAST_EOD'].apply(lambda x: x.replace('.', ','))

# %%
df
# Out:
#     DL_REQUEST_ID    DL_REQUEST_NAME DL_SNAPSHOT_START_TIME DL_SNAPSHOT_TZ  \
# 0    uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 1    uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 2    uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 3    uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 4    uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# ..            ...                ...                    ...            ...
# 127  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 128  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 129  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 130  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 131  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
#
#               IDENTIFIER  RC LAST_UPDATE_DT PX_LAST_EOD
# 0    BVCVPQ3M BVLI Index   0   17-04-24 USD     7,16977
# 1    BVCVPQ6M BVLI Index   0   17-04-24 USD     7,18797
# 2    BVCVPQ01 BVLI Index   0   17-04-24 USD     7,20696
# 3    BVCVPQ02 BVLI Index   0   17-04-24 USD     7,18457
# 4    BVCVPQ03 BVLI Index   0   17-04-24 USD      7,2158
# ..                   ...  ..            ...         ...
# 127  BVCSUN10 BVLI Index   0   17-04-24 USD     5,34715
# 128  BVCSUN15 BVLI Index   0   17-04-24 USD     5,57844
# 129  BVCSUN20 BVLI Index   0   17-04-24 USD     5,70432
# 130  BVCSUN25 BVLI Index   0   17-04-24 USD     5,63201
# 131  BVCSUN30 BVLI Index   0   17-04-24 USD     5,62725
#
# [132 rows x 8 columns]

# %% [markdown]
# **Modalità di scarico delle curve con divisa USD -- RATING A-**

# %%
DF = df[df['IDENTIFIER'].str.startswith('BVCSUN')]

# %%
DF
# Out:
#     DL_REQUEST_ID    DL_REQUEST_NAME DL_SNAPSHOT_START_TIME DL_SNAPSHOT_TZ  \
# 117  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 118  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 119  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 120  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 121  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 122  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 123  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 124  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 125  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 126  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 127  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 128  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 129  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 130  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 131  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
#
#               IDENTIFIER  RC LAST_UPDATE_DT PX_LAST_EOD
# 117  BVCSUN3M BVLI Index   0   17-04-24 USD     5,53773
# 118  BVCSUN6M BVLI Index   0   17-04-24 USD     5,56941
# 119  BVCSUN01 BVLI Index   0   17-04-24 USD     5,47949
# 120  BVCSUN02 BVLI Index   0   17-04-24 USD     5,23049
# 121  BVCSUN03 BVLI Index   0   17-04-24 USD     5,09212
# 122  BVCSUN04 BVLI Index   0   17-04-24 USD     5,05963
# 123  BVCSUN05 BVLI Index   0   17-04-24 USD     5,07006
# 124  BVCSUN07 BVLI Index   0   17-04-24 USD     5,16262
# 125  BVCSUN08 BVLI Index   0   17-04-24 USD     5,20857
# 126  BVCSUN09 BVLI Index   0   17-04-24 USD     5,26074
# 127  BVCSUN10 BVLI Index   0   17-04-24 USD     5,34715
# 128  BVCSUN15 BVLI Index   0   17-04-24 USD     5,57844
# 129  BVCSUN20 BVLI Index   0   17-04-24 USD     5,70432
# 130  BVCSUN25 BVLI Index   0   17-04-24 USD     5,63201
# 131  BVCSUN30 BVLI Index   0   17-04-24 USD     5,62725

# %%
Data = DF.drop(columns=["DL_REQUEST_ID", "DL_REQUEST_NAME", "DL_SNAPSHOT_TZ", "DL_SNAPSHOT_START_TIME", "RC", "IDENTIFIER", "DL_SNAPSHOT_START_TIME","LAST_UPDATE_DT"])

# %%
DATA = Data.transpose()

# %%
DATA
# Out:
#                  117      118      119      120      121      122      123  \
# PX_LAST_EOD  5,53773  5,56941  5,47949  5,23049  5,09212  5,05963  5,07006
#
#                  124      125      126      127      128      129      130  \
# PX_LAST_EOD  5,16262  5,20857  5,26074  5,34715  5,57844  5,70432  5,63201
#
#                  131
# PX_LAST_EOD  5,62725

# %%
file_name = 'tassi-Ameno-USD.xlsx'

# %%
DATA.to_excel(file_name)
print('DataFrame is written to Excel File successfully.')
# Out:
# DataFrame is written to Excel File successfully.

# %%
# opening the source excel file
wbo = openpyxl.load_workbook(file_name)

# %%
#attach the ranges to the sheet
wso = wbo["Sheet1"]["B2":"P2"]

# %%
# opening the destination excel file
wbd = openpyxl.load_workbook("/content/Condizioni economiche Fin. IC BREVE E MLT Eni II trimestre 2024.xlsm", keep_vba=True)

# %%
tab_name = df.at[0, 'LAST_UPDATE_DT']

# %%
#attach the ranges to the sheet
wsd = wbd[tab_name]["C4":"Q4"]

# %%
#step1 : pair the rows
for row1,row2 in zip(wso,wsd):
    #within the row pair, pair the cells
    for cell1, cell2 in zip(row1,row2): cell2.value = cell1.value

# %%
#save document
wbd.save('Condizioni economiche Fin. IC BREVE E MLT Eni II trimestre 2024.xlsm')

# %% [markdown]
# **Modalità di scarico delle curve con divisa USD -- RATING BBB+**

# %%
DF = df[df['IDENTIFIER'].str.startswith('IGUUAA')]

# %%
DF
# Out:
#     DL_REQUEST_ID    DL_REQUEST_NAME DL_SNAPSHOT_START_TIME DL_SNAPSHOT_TZ  \
# 102  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 103  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 104  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 105  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 106  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 107  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 108  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 109  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 110  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 111  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 112  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 113  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 114  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 115  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 116  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
#
#               IDENTIFIER  RC LAST_UPDATE_DT PX_LAST_EOD
# 102  IGUUAA3M BVLI Index   0   17-04-24 USD     5,77368
# 103  IGUUAA6M BVLI Index   0   17-04-24 USD     5,79634
# 104  IGUUAA01 BVLI Index   0   17-04-24 USD     5,70216
# 105  IGUUAA02 BVLI Index   0   17-04-24 USD     5,46324
# 106  IGUUAA03 BVLI Index   0   17-04-24 USD     5,33215
# 107  IGUUAA04 BVLI Index   0   17-04-24 USD     5,29908
# 108  IGUUAA05 BVLI Index   0   17-04-24 USD     5,30529
# 109  IGUUAA07 BVLI Index   0   17-04-24 USD     5,38192
# 110  IGUUAA08 BVLI Index   0   17-04-24 USD     5,42022
# 111  IGUUAA09 BVLI Index   0   17-04-24 USD     5,46401
# 112  IGUUAA10 BVLI Index   0   17-04-24 USD     5,53828
# 113  IGUUAA15 BVLI Index   0   17-04-24 USD     5,73108
# 114  IGUUAA20 BVLI Index   0   17-04-24 USD      5,8341
# 115  IGUUAA25 BVLI Index   0   17-04-24 USD     5,76473
# 116  IGUUAA30 BVLI Index   0   17-04-24 USD     5,76092

# %%
Data = DF.drop(columns=["DL_REQUEST_ID", "DL_REQUEST_NAME", "DL_SNAPSHOT_TZ", "DL_SNAPSHOT_START_TIME", "RC", "IDENTIFIER", "DL_SNAPSHOT_START_TIME","LAST_UPDATE_DT"])

# %%
DATA = Data.transpose()

# %%
DATA
# Out:
#                  102      103      104      105      106      107      108  \
# PX_LAST_EOD  5,77368  5,79634  5,70216  5,46324  5,33215  5,29908  5,30529
#
#                  109      110      111      112      113     114      115  \
# PX_LAST_EOD  5,38192  5,42022  5,46401  5,53828  5,73108  5,8341  5,76473
#
#                  116
# PX_LAST_EOD  5,76092

# %%
file_name = 'tassi-BBBpiu-USD.xlsx'

# %%
DATA.to_excel(file_name)
print('DataFrame is written to Excel File successfully.')
# Out:
# DataFrame is written to Excel File successfully.

# %%
# opening the source excel file
wbo = openpyxl.load_workbook(file_name)

# %%
#attach the ranges to the sheet
wso = wbo["Sheet1"]["B2":"P2"]

# %%
# opening the destination excel file
wbd = openpyxl.load_workbook("/content/Condizioni economiche Fin. IC BREVE E MLT Eni II trimestre 2024.xlsm", keep_vba=True)

# %%
tab_name = df.at[0, 'LAST_UPDATE_DT']

# %%
#attach the ranges to the sheet
wsd = wbd[tab_name]["C5":"Q5"]

# %%
#step1 : pair the rows
for row1,row2 in zip(wso,wsd):
    #within the row pair, pair the cells
    for cell1, cell2 in zip(row1,row2): cell2.value = cell1.value

# %%
#save document
wbd.save('Condizioni economiche Fin. IC BREVE E MLT Eni II trimestre 2024.xlsm')

# %% [markdown]
# **Modalità di scarico delle curve con divisa USD -- RATING BBB**

# %%
DF = df[df['IDENTIFIER'].str.startswith('IGUUAD')]

# %%
DF
# Out:
#    DL_REQUEST_ID    DL_REQUEST_NAME DL_SNAPSHOT_START_TIME DL_SNAPSHOT_TZ  \
# 75  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 76  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 77  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 78  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 79  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 80  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 81  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 82  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 83  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 84  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 85  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 86  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 87  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 88  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 89  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
#
#              IDENTIFIER  RC LAST_UPDATE_DT PX_LAST_EOD
# 75  IGUUAD3M BVLI Index   0   17-04-24 USD      5,8947
# 76  IGUUAD6M BVLI Index   0   17-04-24 USD     5,89904
# 77  IGUUAD01 BVLI Index   0   17-04-24 USD     5,80347
# 78  IGUUAD02 BVLI Index   0   17-04-24 USD     5,56378
# 79  IGUUAD03 BVLI Index   0   17-04-24 USD     5,44075
# 80  IGUUAD04 BVLI Index   0   17-04-24 USD     5,41769
# 81  IGUUAD05 BVLI Index   0   17-04-24 USD      5,4375
# 82  IGUUAD07 BVLI Index   0   17-04-24 USD     5,55381
# 83  IGUUAD08 BVLI Index   0   17-04-24 USD     5,60961
# 84  IGUUAD09 BVLI Index   0   17-04-24 USD     5,66786
# 85  IGUUAD10 BVLI Index   0   17-04-24 USD     5,75326
# 86  IGUUAD15 BVLI Index   0   17-04-24 USD     5,96624
# 87  IGUUAD20 BVLI Index   0   17-04-24 USD     6,04599
# 88  IGUUAD25 BVLI Index   0   17-04-24 USD     5,95321
# 89  IGUUAD30 BVLI Index   0   17-04-24 USD      5,9534

# %%
Data = DF.drop(columns=["DL_REQUEST_ID", "DL_REQUEST_NAME", "DL_SNAPSHOT_TZ", "DL_SNAPSHOT_START_TIME", "RC", "IDENTIFIER", "DL_SNAPSHOT_START_TIME","LAST_UPDATE_DT"])

# %%
Data = DF.drop(columns=["DL_REQUEST_ID", "DL_REQUEST_NAME", "DL_SNAPSHOT_TZ", "DL_SNAPSHOT_START_TIME", "RC", "IDENTIFIER", "DL_SNAPSHOT_START_TIME","LAST_UPDATE_DT"])

# %%
DATA = Data.transpose()

# %%
DATA
# Out:
#                  75       76       77       78       79       80      81  \
# PX_LAST_EOD  5,8947  5,89904  5,80347  5,56378  5,44075  5,41769  5,4375
#
#                   82       83       84       85       86       87       88  \
# PX_LAST_EOD  5,55381  5,60961  5,66786  5,75326  5,96624  6,04599  5,95321
#
#                  89
# PX_LAST_EOD  5,9534

# %%
file_name = 'tassi-BBB-USD.xlsx'

# %%
DATA.to_excel(file_name)
print('DataFrame is written to Excel File successfully.')
# Out:
# DataFrame is written to Excel File successfully.

# %%
# opening the source excel file
wbo = openpyxl.load_workbook(file_name)

# %%
#attach the ranges to the sheet
wso = wbo["Sheet1"]["B2":"P2"]

# %%
# opening the destination excel file
wbd = openpyxl.load_workbook("/content/Condizioni economiche Fin. IC BREVE E MLT Eni II trimestre 2024.xlsm", keep_vba=True)

# %%
tab_name = df.at[0, 'LAST_UPDATE_DT']

# %%
print(tab_name)
# Out:
# 17-04-24 USD

# %%
#attach the ranges to the sheet
wsd = wbd[tab_name]["C6":"Q6"]

# %%
#step1 : pair the rows
for row1,row2 in zip(wso,wsd):
    #within the row pair, pair the cells
    for cell1, cell2 in zip(row1,row2): cell2.value = cell1.value

# %%
#save document
wbd.save('Condizioni economiche Fin. IC BREVE E MLT Eni II trimestre 2024.xlsm')

# %% [markdown]
# **Modalità di scarico delle curve con divisa USD -- RATING BBB-**

# %%
DF = df[df['IDENTIFIER'].str.startswith('IGUUAB')]

# %%
DF
# Out:
#    DL_REQUEST_ID    DL_REQUEST_NAME DL_SNAPSHOT_START_TIME DL_SNAPSHOT_TZ  \
# 60  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 61  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 62  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 63  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 64  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 65  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 66  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 67  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 68  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 69  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 70  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 71  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 72  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 73  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 74  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
#
#              IDENTIFIER  RC LAST_UPDATE_DT PX_LAST_EOD
# 60  IGUUAB3M BVLI Index   0   17-04-24 USD      6,1194
# 61  IGUUAB6M BVLI Index   0   17-04-24 USD     6,12206
# 62  IGUUAB01 BVLI Index   0   17-04-24 USD      6,0524
# 63  IGUUAB02 BVLI Index   0   17-04-24 USD     5,85817
# 64  IGUUAB03 BVLI Index   0   17-04-24 USD     5,76692
# 65  IGUUAB04 BVLI Index   0   17-04-24 USD     5,76246
# 66  IGUUAB05 BVLI Index   0   17-04-24 USD     5,79667
# 67  IGUUAB07 BVLI Index   0   17-04-24 USD     5,93577
# 68  IGUUAB08 BVLI Index   0   17-04-24 USD     6,00037
# 69  IGUUAB09 BVLI Index   0   17-04-24 USD     6,06682
# 70  IGUUAB10 BVLI Index   0   17-04-24 USD     6,15504
# 71  IGUUAB15 BVLI Index   0   17-04-24 USD     6,41147
# 72  IGUUAB20 BVLI Index   0   17-04-24 USD     6,51483
# 73  IGUUAB25 BVLI Index   0   17-04-24 USD     6,43654
# 74  IGUUAB30 BVLI Index   0   17-04-24 USD      6,4222

# %%
Data = DF.drop(columns=["DL_REQUEST_ID", "DL_REQUEST_NAME", "DL_SNAPSHOT_TZ", "DL_SNAPSHOT_START_TIME", "RC", "IDENTIFIER", "DL_SNAPSHOT_START_TIME","LAST_UPDATE_DT"])

# %%
Data = DF.drop(columns=["DL_REQUEST_ID", "DL_REQUEST_NAME", "DL_SNAPSHOT_TZ", "DL_SNAPSHOT_START_TIME", "RC", "IDENTIFIER", "DL_SNAPSHOT_START_TIME","LAST_UPDATE_DT"])

# %%
DATA = Data.transpose()

# %%
DATA
# Out:
#                  60       61      62       63       64       65       66  \
# PX_LAST_EOD  6,1194  6,12206  6,0524  5,85817  5,76692  5,76246  5,79667
#
#                   67       68       69       70       71       72       73  \
# PX_LAST_EOD  5,93577  6,00037  6,06682  6,15504  6,41147  6,51483  6,43654
#
#                  74
# PX_LAST_EOD  6,4222

# %%
file_name = 'tassi-BBBmeno-USD.xlsx'

# %%
DATA.to_excel(file_name)
print('DataFrame is written to Excel File successfully.')
# Out:
# DataFrame is written to Excel File successfully.

# %%
# opening the source excel file
wbo = openpyxl.load_workbook(file_name)

# %%
#attach the ranges to the sheet
wso = wbo["Sheet1"]["B2":"P2"]

# %%
# opening the destination excel file
wbd = openpyxl.load_workbook("/content/Condizioni economiche Fin. IC BREVE E MLT Eni II trimestre 2024.xlsm", keep_vba=True)

# %%
tab_name = df.at[0, 'LAST_UPDATE_DT']

# %%
print(tab_name)
# Out:
# 17-04-24 USD

# %%
#attach the ranges to the sheet
wsd = wbd[tab_name]["C7":"Q7"]

# %%
#step1 : pair the rows
for row1,row2 in zip(wso,wsd):
    #within the row pair, pair the cells
    for cell1, cell2 in zip(row1,row2): cell2.value = cell1.value

# %%
#save document
wbd.save('Condizioni economiche Fin. IC BREVE E MLT Eni II trimestre 2024.xlsm')

# %% [markdown]
# **Modalità di scarico delle curve con divisa USD -- RATING BB+**

# %%
DF = df[df['IDENTIFIER'].str.startswith('BVCVPT')]

# %%
DF
# Out:
#     DL_REQUEST_ID    DL_REQUEST_NAME DL_SNAPSHOT_START_TIME DL_SNAPSHOT_TZ  \
# 90   uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 91   uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 92   uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 93   uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 94   uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 95   uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 96   uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 97   uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 98   uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 99   uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 100  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 101  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
#
#               IDENTIFIER  RC LAST_UPDATE_DT PX_LAST_EOD
# 90   BVCVPT3M BVLI Index   0   17-04-24 USD     6,36934
# 91   BVCVPT6M BVLI Index   0   17-04-24 USD     6,35968
# 92   BVCVPT01 BVLI Index   0   17-04-24 USD     6,32268
# 93   BVCVPT02 BVLI Index   0   17-04-24 USD     6,24184
# 94   BVCVPT03 BVLI Index   0   17-04-24 USD     6,24545
# 95   BVCVPT04 BVLI Index   0   17-04-24 USD     6,31092
# 96   BVCVPT05 BVLI Index   0   17-04-24 USD     6,39593
# 97   BVCVPT07 BVLI Index   0   17-04-24 USD     6,56295
# 98   BVCVPT08 BVLI Index   0   17-04-24 USD     6,61176
# 99   BVCVPT09 BVLI Index   0   17-04-24 USD      6,6589
# 100  BVCVPT10 BVLI Index   0   17-04-24 USD     6,73186
# 101  BVCVPT15 BVLI Index   0   17-04-24 USD     6,96309

# %%
Data = DF.drop(columns=["DL_REQUEST_ID", "DL_REQUEST_NAME", "DL_SNAPSHOT_TZ", "DL_SNAPSHOT_START_TIME", "RC", "IDENTIFIER", "DL_SNAPSHOT_START_TIME","LAST_UPDATE_DT"])

# %%
Data = DF.drop(columns=["DL_REQUEST_ID", "DL_REQUEST_NAME", "DL_SNAPSHOT_TZ", "DL_SNAPSHOT_START_TIME", "RC", "IDENTIFIER", "DL_SNAPSHOT_START_TIME","LAST_UPDATE_DT"])

# %%
DATA = Data.transpose()

# %%
DATA
# Out:
#                  90       91       92       93       94       95       96   \
# PX_LAST_EOD  6,36934  6,35968  6,32268  6,24184  6,24545  6,31092  6,39593
#
#                  97       98      99       100      101
# PX_LAST_EOD  6,56295  6,61176  6,6589  6,73186  6,96309

# %%
file_name = 'tassi-BBpiu-USD.xlsx'

# %%
DATA.to_excel(file_name)
print('DataFrame is written to Excel File successfully.')
# Out:
# DataFrame is written to Excel File successfully.

# %%
# opening the source excel file
wbo = openpyxl.load_workbook(file_name)

# %%
#attach the ranges to the sheet
wso = wbo["Sheet1"]["B2":"P2"]

# %%
# opening the destination excel file
wbd = openpyxl.load_workbook("/content/Condizioni economiche Fin. IC BREVE E MLT Eni II trimestre 2024.xlsm", keep_vba=True)

# %%
tab_name = df.at[0, 'LAST_UPDATE_DT']

# %%
print(tab_name)
# Out:
# 17-04-24 USD

# %%
#attach the ranges to the sheet
wsd = wbd[tab_name]["C8":"Q8"]

# %%
#step1 : pair the rows
for row1,row2 in zip(wso,wsd):
    #within the row pair, pair the cells
    for cell1, cell2 in zip(row1,row2): cell2.value = cell1.value

# %%
#save document
wbd.save('Condizioni economiche Fin. IC BREVE E MLT Eni II trimestre 2024.xlsm')

# %% [markdown]
# **Modalità di scarico delle curve con divisa USD -- RATING BB**

# %%
DF = df[df['IDENTIFIER'].str.startswith('BVCVXK')]

# %%
DF
# Out:
#    DL_REQUEST_ID    DL_REQUEST_NAME DL_SNAPSHOT_START_TIME DL_SNAPSHOT_TZ  \
# 48  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 49  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 50  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 51  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 52  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 53  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 54  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 55  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 56  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 57  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 58  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 59  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
#
#              IDENTIFIER  RC LAST_UPDATE_DT PX_LAST_EOD
# 48  BVCVXK3M BVLI Index   0   17-04-24 USD     6,52228
# 49  BVCVXK6M BVLI Index   0   17-04-24 USD     6,52479
# 50  BVCVXK01 BVLI Index   0   17-04-24 USD     6,50431
# 51  BVCVXK02 BVLI Index   0   17-04-24 USD     6,40473
# 52  BVCVXK03 BVLI Index   0   17-04-24 USD     6,41318
# 53  BVCVXK04 BVLI Index   0   17-04-24 USD     6,48133
# 54  BVCVXK05 BVLI Index   0   17-04-24 USD     6,56391
# 55  BVCVXK07 BVLI Index   0   17-04-24 USD     6,69353
# 56  BVCVXK08 BVLI Index   0   17-04-24 USD     6,72104
# 57  BVCVXK09 BVLI Index   0   17-04-24 USD     6,75017
# 58  BVCVXK10 BVLI Index   0   17-04-24 USD     6,79582
# 59  BVCVXK15 BVLI Index   0   17-04-24 USD     7,00223

# %%
Data = DF.drop(columns=["DL_REQUEST_ID", "DL_REQUEST_NAME", "DL_SNAPSHOT_TZ", "DL_SNAPSHOT_START_TIME", "RC", "IDENTIFIER", "DL_SNAPSHOT_START_TIME","LAST_UPDATE_DT"])

# %%
DATA = Data.transpose()

# %%
DATA
# Out:
#                   48       49       50       51       52       53       54  \
# PX_LAST_EOD  6,52228  6,52479  6,50431  6,40473  6,41318  6,48133  6,56391
#
#                   55       56       57       58       59
# PX_LAST_EOD  6,69353  6,72104  6,75017  6,79582  7,00223

# %%
file_name = 'tassi-BB-USD.xlsx'

# %%
DATA.to_excel(file_name)
print('DataFrame is written to Excel File successfully.')
# Out:
# DataFrame is written to Excel File successfully.

# %%
# opening the source excel file
wbo = openpyxl.load_workbook(file_name)

# %%
#attach the ranges to the sheet
wso = wbo["Sheet1"]["B2":"P2"]

# %%
# opening the destination excel file
wbd = openpyxl.load_workbook("/content/Condizioni economiche Fin. IC BREVE E MLT Eni II trimestre 2024.xlsm", keep_vba=True)

# %%
tab_name = df.at[0, 'LAST_UPDATE_DT']

# %%
print(tab_name)
# Out:
# 17-04-24 USD

# %%
#attach the ranges to the sheet
wsd = wbd[tab_name]["C9":"Q9"]

# %%
#step1 : pair the rows
for row1,row2 in zip(wso,wsd):
    #within the row pair, pair the cells
    for cell1, cell2 in zip(row1,row2): cell2.value = cell1.value

# %%
#save document
wbd.save('Condizioni economiche Fin. IC BREVE E MLT Eni II trimestre 2024.xlsm')

# %% [markdown]
# **Modalità di scarico delle curve con divisa USD -- RATING BB-**

# %%
DF = df[df['IDENTIFIER'].str.startswith('BVCVPS')]

# %%
DF
# Out:
#    DL_REQUEST_ID    DL_REQUEST_NAME DL_SNAPSHOT_START_TIME DL_SNAPSHOT_TZ  \
# 36  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 37  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 38  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 39  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 40  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 41  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 42  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 43  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 44  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 45  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 46  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 47  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
#
#              IDENTIFIER  RC LAST_UPDATE_DT PX_LAST_EOD
# 36  BVCVPS3M BVLI Index   0   17-04-24 USD     6,60161
# 37  BVCVPS6M BVLI Index   0   17-04-24 USD     6,60616
# 38  BVCVPS01 BVLI Index   0   17-04-24 USD     6,58054
# 39  BVCVPS02 BVLI Index   0   17-04-24 USD     6,46141
# 40  BVCVPS03 BVLI Index   0   17-04-24 USD     6,46771
# 41  BVCVPS04 BVLI Index   0   17-04-24 USD     6,55694
# 42  BVCVPS05 BVLI Index   0   17-04-24 USD     6,66982
# 43  BVCVPS07 BVLI Index   0   17-04-24 USD      6,8511
# 44  BVCVPS08 BVLI Index   0   17-04-24 USD     6,90699
# 45  BVCVPS09 BVLI Index   0   17-04-24 USD     6,95789
# 46  BVCVPS10 BVLI Index   0   17-04-24 USD     7,01846
# 47  BVCVPS15 BVLI Index   0   17-04-24 USD     7,24927

# %%
Data = DF.drop(columns=["DL_REQUEST_ID", "DL_REQUEST_NAME", "DL_SNAPSHOT_TZ", "DL_SNAPSHOT_START_TIME", "RC", "IDENTIFIER", "DL_SNAPSHOT_START_TIME","LAST_UPDATE_DT"])

# %%
DATA = Data.transpose()

# %%
DATA
# Out:
#                   36       37       38       39       40       41       42  \
# PX_LAST_EOD  6,60161  6,60616  6,58054  6,46141  6,46771  6,55694  6,66982
#
#                  43       44       45       46       47
# PX_LAST_EOD  6,8511  6,90699  6,95789  7,01846  7,24927

# %%
file_name = 'tassi-BBmeno-USD.xlsx'

# %%
DATA.to_excel(file_name)
print('DataFrame is written to Excel File successfully.')
# Out:
# DataFrame is written to Excel File successfully.

# %%
# opening the source excel file
wbo = openpyxl.load_workbook(file_name)

# %%
#attach the ranges to the sheet
wso = wbo["Sheet1"]["B2":"P2"]

# %%
# opening the destination excel file
wbd = openpyxl.load_workbook("/content/Condizioni economiche Fin. IC BREVE E MLT Eni II trimestre 2024.xlsm", keep_vba=True)

# %%
tab_name = df.at[0, 'LAST_UPDATE_DT']

# %%
print(tab_name)
# Out:
# 17-04-24 USD

# %%
#attach the ranges to the sheet
wsd = wbd[tab_name]["C10":"Q10"]

# %%
#step1 : pair the rows
for row1,row2 in zip(wso,wsd):
    #within the row pair, pair the cells
    for cell1, cell2 in zip(row1,row2): cell2.value = cell1.value

# %%
#save document
wbd.save('Condizioni economiche Fin. IC BREVE E MLT Eni II trimestre 2024.xlsm')

# %% [markdown]
# **Modalità di scarico delle curve con divisa USD -- RATING B+**

# %%
DF = df[df['IDENTIFIER'].str.startswith('BVCVPR')]

# %%
DF
# Out:
#    DL_REQUEST_ID    DL_REQUEST_NAME DL_SNAPSHOT_START_TIME DL_SNAPSHOT_TZ  \
# 24  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 25  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 26  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 27  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 28  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 29  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 30  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 31  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 32  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 33  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 34  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 35  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
#
#              IDENTIFIER  RC LAST_UPDATE_DT PX_LAST_EOD
# 24  BVCVPR3M BVLI Index   0   17-04-24 USD      6,6947
# 25  BVCVPR6M BVLI Index   0   17-04-24 USD     6,70141
# 26  BVCVPR01 BVLI Index   0   17-04-24 USD     6,69343
# 27  BVCVPR02 BVLI Index   0   17-04-24 USD     6,59492
# 28  BVCVPR03 BVLI Index   0   17-04-24 USD     6,61342
# 29  BVCVPR04 BVLI Index   0   17-04-24 USD      6,7244
# 30  BVCVPR05 BVLI Index   0   17-04-24 USD     6,83131
# 31  BVCVPR07 BVLI Index   0   17-04-24 USD     7,01949
# 32  BVCVPR08 BVLI Index   0   17-04-24 USD     7,05518
# 33  BVCVPR09 BVLI Index   0   17-04-24 USD     7,08469
# 34  BVCVPR10 BVLI Index   0   17-04-24 USD     7,12168
# 35  BVCVPR15 BVLI Index   0   17-04-24 USD      7,3347

# %%
Data = DF.drop(columns=["DL_REQUEST_ID", "DL_REQUEST_NAME", "DL_SNAPSHOT_TZ", "DL_SNAPSHOT_START_TIME", "RC", "IDENTIFIER", "DL_SNAPSHOT_START_TIME","LAST_UPDATE_DT"])

# %%
DATA = Data.transpose()

# %%
DATA
# Out:
#                  24       25       26       27       28      29       30  \
# PX_LAST_EOD  6,6947  6,70141  6,69343  6,59492  6,61342  6,7244  6,83131
#
#                   31       32       33       34      35
# PX_LAST_EOD  7,01949  7,05518  7,08469  7,12168  7,3347

# %%
file_name = 'tassi-Bpiu-USD.xlsx'

# %%
DATA.to_excel(file_name)
print('DataFrame is written to Excel File successfully.')
# Out:
# DataFrame is written to Excel File successfully.

# %%
# opening the source excel file
wbo = openpyxl.load_workbook(file_name)

# %%
#attach the ranges to the sheet
wso = wbo["Sheet1"]["B2":"P2"]

# %%
# opening the destination excel file
wbd = openpyxl.load_workbook("/content/Condizioni economiche Fin. IC BREVE E MLT Eni II trimestre 2024.xlsm", keep_vba=True)

# %%
tab_name = df.at[0, 'LAST_UPDATE_DT']

# %%
print(tab_name)
# Out:
# 17-04-24 USD

# %%
#attach the ranges to the sheet
wsd = wbd[tab_name]["C11":"Q11"]

# %%
#step1 : pair the rows
for row1,row2 in zip(wso,wsd):
    #within the row pair, pair the cells
    for cell1, cell2 in zip(row1,row2): cell2.value = cell1.value

# %%
#save document
wbd.save('Condizioni economiche Fin. IC BREVE E MLT Eni II trimestre 2024.xlsm')

# %% [markdown]
# **Modalità di scarico delle curve con divisa USD -- RATING B**

# %%
DF = df[df['IDENTIFIER'].str.startswith('BVCVPP')]

# %%
DF
# Out:
#    DL_REQUEST_ID    DL_REQUEST_NAME DL_SNAPSHOT_START_TIME DL_SNAPSHOT_TZ  \
# 12  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 13  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 14  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 15  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 16  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 17  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 18  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 19  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 20  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 21  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 22  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 23  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
#
#              IDENTIFIER  RC LAST_UPDATE_DT PX_LAST_EOD
# 12  BVCVPP3M BVLI Index   0   17-04-24 USD     6,78217
# 13  BVCVPP6M BVLI Index   0   17-04-24 USD     6,79796
# 14  BVCVPP01 BVLI Index   0   17-04-24 USD     6,80523
# 15  BVCVPP02 BVLI Index   0   17-04-24 USD      6,7741
# 16  BVCVPP03 BVLI Index   0   17-04-24 USD     6,86651
# 17  BVCVPP04 BVLI Index   0   17-04-24 USD     7,02953
# 18  BVCVPP05 BVLI Index   0   17-04-24 USD     7,15188
# 19  BVCVPP07 BVLI Index   0   17-04-24 USD     7,32583
# 20  BVCVPP08 BVLI Index   0   17-04-24 USD     7,37125
# 21  BVCVPP09 BVLI Index   0   17-04-24 USD     7,40149
# 22  BVCVPP10 BVLI Index   0   17-04-24 USD     7,44126
# 23  BVCVPP15 BVLI Index   0   17-04-24 USD      7,6768

# %%
Data = DF.drop(columns=["DL_REQUEST_ID", "DL_REQUEST_NAME", "DL_SNAPSHOT_TZ", "DL_SNAPSHOT_START_TIME", "RC", "IDENTIFIER", "DL_SNAPSHOT_START_TIME","LAST_UPDATE_DT"])

# %%
DATA = Data.transpose()

# %%
DATA
# Out:
#                   12       13       14      15       16       17       18  \
# PX_LAST_EOD  6,78217  6,79796  6,80523  6,7741  6,86651  7,02953  7,15188
#
#                   19       20       21       22      23
# PX_LAST_EOD  7,32583  7,37125  7,40149  7,44126  7,6768

# %%
file_name = 'tassi-B-USD.xlsx'

# %%
DATA.to_excel(file_name)
print('DataFrame is written to Excel File successfully.')
# Out:
# DataFrame is written to Excel File successfully.

# %%
# opening the source excel file
wbo = openpyxl.load_workbook(file_name)

# %%
#attach the ranges to the sheet
wso = wbo["Sheet1"]["B2":"P2"]

# %%
# opening the destination excel file
wbd = openpyxl.load_workbook("/content/Condizioni economiche Fin. IC BREVE E MLT Eni II trimestre 2024.xlsm", keep_vba=True)

# %%
tab_name = df.at[0, 'LAST_UPDATE_DT']

# %%
print(tab_name)
# Out:
# 17-04-24 USD

# %%
#attach the ranges to the sheet
wsd = wbd[tab_name]["C12":"Q12"]

# %%
#step1 : pair the rows
for row1,row2 in zip(wso,wsd):
    #within the row pair, pair the cells
    for cell1, cell2 in zip(row1,row2): cell2.value = cell1.value

# %%
#save document
wbd.save('Condizioni economiche Fin. IC BREVE E MLT Eni II trimestre 2024.xlsm')

# %% [markdown]
# **Modalità di scarico delle curve con divisa USD -- RATING B-**

# %%
DF = df[df['IDENTIFIER'].str.startswith('BVCVPQ')]

# %%
DF
# Out:
#    DL_REQUEST_ID    DL_REQUEST_NAME DL_SNAPSHOT_START_TIME DL_SNAPSHOT_TZ  \
# 0   uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 1   uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 2   uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 3   uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 4   uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 5   uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 6   uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 7   uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 8   uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 9   uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 10  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
# 11  uPhyv4323syT  USDUSAIndustrials    2024-04-18T16:38:04            BST
#
#              IDENTIFIER  RC LAST_UPDATE_DT PX_LAST_EOD
# 0   BVCVPQ3M BVLI Index   0   17-04-24 USD     7,16977
# 1   BVCVPQ6M BVLI Index   0   17-04-24 USD     7,18797
# 2   BVCVPQ01 BVLI Index   0   17-04-24 USD     7,20696
# 3   BVCVPQ02 BVLI Index   0   17-04-24 USD     7,18457
# 4   BVCVPQ03 BVLI Index   0   17-04-24 USD      7,2158
# 5   BVCVPQ04 BVLI Index   0   17-04-24 USD      7,3326
# 6   BVCVPQ05 BVLI Index   0   17-04-24 USD     7,46014
# 7   BVCVPQ07 BVLI Index   0   17-04-24 USD     7,67004
# 8   BVCVPQ08 BVLI Index   0   17-04-24 USD     7,70659
# 9   BVCVPQ09 BVLI Index   0   17-04-24 USD     7,72789
# 10  BVCVPQ10 BVLI Index   0   17-04-24 USD     7,75876
# 11  BVCVPQ15 BVLI Index   0   17-04-24 USD     7,94701

# %%
Data = DF.drop(columns=["DL_REQUEST_ID", "DL_REQUEST_NAME", "DL_SNAPSHOT_TZ", "DL_SNAPSHOT_START_TIME", "RC", "IDENTIFIER", "DL_SNAPSHOT_START_TIME","LAST_UPDATE_DT"])

# %%
DATA = Data.transpose()

# %%
DATA
# Out:
#                   0        1        2        3       4       5        6   \
# PX_LAST_EOD  7,16977  7,18797  7,20696  7,18457  7,2158  7,3326  7,46014
#
#                   7        8        9        10       11
# PX_LAST_EOD  7,67004  7,70659  7,72789  7,75876  7,94701

# %%
file_name = 'tassi-Bmeno-USD.xlsx'

# %%
DATA.to_excel(file_name)
print('DataFrame is written to Excel File successfully.')
# Out:
# DataFrame is written to Excel File successfully.

# %%
# opening the source excel file
wbo = openpyxl.load_workbook(file_name)

# %%
#attach the ranges to the sheet
wso = wbo["Sheet1"]["B2":"P2"]

# %%
# opening the destination excel file
wbd = openpyxl.load_workbook("/content/Condizioni economiche Fin. IC BREVE E MLT Eni II trimestre 2024.xlsm", keep_vba=True)

# %%
tab_name = df.at[0, 'LAST_UPDATE_DT']

# %%
print(tab_name)
# Out:
# 17-04-24 USD

# %%
#attach the ranges to the sheet
wsd = wbd[tab_name]["C13":"Q13"]

# %%
#step1 : pair the rows
for row1,row2 in zip(wso,wsd):
    #within the row pair, pair the cells
    for cell1, cell2 in zip(row1,row2): cell2.value = cell1.value

# %%
#save document
wbd.save('Condizioni economiche Fin. IC BREVE E MLT Eni II trimestre 2024.xlsm')
